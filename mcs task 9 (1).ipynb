# %%
import requests
data = requests.get('https://api.coinmarketcap.com/v1/ticker/?convert=RUB').json()
#print(type(data))
#print(type(data[0]))
print(data[0].keys())
print()
# Out:
# dict_keys(['id', 'name', 'symbol', 'rank', 'price_usd', 'price_btc', '24h_volume_usd', 'market_cap_usd', 'available_supply', 'total_supply', 'max_supply', 'percent_change_1h', 'percent_change_24h', 'percent_change_7d', 'last_updated', 'price_rub', '24h_volume_rub', 'market_cap_rub'])

# %%
def print_all():
    for n in range(len(data)):
        print(data[n]['name'] + ' ' + data[n]['price_rub'])
        
print_all()
# Out:
# Bitcoin 431905.457019
# Ethereum 14408.8832075
# XRP 35.4770249312
# Bitcoin Cash 40963.1930892
# EOS 374.240078838
# Stellar 17.0911903715
# Litecoin 3580.7814133
# Cardano 5.2141903011
# Monero 7340.18088441
# Tether 65.7732720475
# TRON 1.5831162189
# Dash 11014.3098713
# IOTA 33.2554493672
# Binance Coin 649.408128041
# NEO 1110.46864243
# Ethereum Classic 636.566767389
# NEM 6.3944165896
# Tezos 88.0627687847
# Zcash 8497.99184247
# VeChain 0.7182728158
# Bitcoin Gold 2083.49202557
# Maker 44626.3780816
# OmiseGO 225.636987427
# Dogecoin 0.2409824113
# 0x 49.9100563698
# Qtum 270.956973431
# Decred 2702.35951776
# Ontology 111.35256085
# Basic Attention Token 22.4137260868
# Lisk 190.650226059
# Aeternity 86.3442766893
# Zilliqa 2.3110469006
# Bitcoin Diamond 116.304039221
# BitShares 6.5284275203
# Bytecoin 0.0932770743
# Nano 128.729426675
# ICON 42.6694091225
# Siacoin 0.4264014464
# DigiByte 1.4075709378
# Steem 54.3469145805
# Pundi X 0.1014790753
# Verge 0.9160640366
# Bytom 13.1342825665
# Waves 121.420548376
# Aurora 1.8418995558
# Metaverse ETP 211.331878902
# Chainlink 32.0499304035
# Augur 981.990131255
# Golem 11.1857559663
# TrueUSD 66.2426696561
# Stratis 105.709935157
# Holo 0.0735827693
# Electroneum 1.1529384323
# Komodo 81.5971406007
# Paxos Standard Token 65.9768320555
# USD Coin 66.5164151191
# Status 2.5203551118
# Populous 231.953580979
# Waltonchain 206.750924837
# Cryptonex 135.494913021
# Wanchain 69.471298698
# MaidSafeCoin 16.1337032555
# Ardor 7.0313309328
# IOST 0.814396597
# Mithril 17.5311357817
# KuCoin Shares 73.8568240968
# Aion 27.2296959023
# Ravencoin 2.8918410665
# Nexo 11.0127277503
# Bancor 92.6800725642
# WAX 6.3980773664
# Loopring 7.5143236039
# DigixDAO 2738.36721581
# GXChain 91.1914274849
# Decentraland 5.166116874
# aelf 21.5057489947
# Ark 50.6057093612
# HyperCash 121.342690622
# Huobi Token 105.2059149
# Polymath 18.1355378573
# ReddCoin 0.1795478015
# Horizen 1012.79954155
# Veritaseum 2526.2921673
# PIVX 90.4317822482
# MonaCoin 78.6449939938
# QASH 14.2141769127
# Dentacoin 0.0144196972
# CyberMiles 6.0988487756
# MOAC 74.0752679072
# Crypto.com 291.459554139
# Dai 65.990176692
# Loom Network 7.5790019467
# Nxt 4.4753126881
# Mixin 10059.5435832
# FunFair 0.8577762208
# Nebulas 96.6912939115
# Theta Token 6.110125695
# Revain 12.7467431904
# ETERNAL TOKEN 70.2169433286
# Dropil 0.1901488271

# %%
def print_changes():
    for n in range(len(data)):
        print(data[n]['name'] + ' ' + data[n]['percent_change_24h'] + '%')
        
print_changes()
# Out:
# Bitcoin 1.16%
# Ethereum 0.54%
# XRP -0.5%
# Bitcoin Cash 1.06%
# EOS -0.28%
# Stellar -1.85%
# Litecoin -1.64%
# Cardano -1.3%
# Monero -1.29%
# Tether 0.02%
# TRON -1.91%
# Dash -1.86%
# IOTA -1.13%
# Binance Coin 0.89%
# NEO -0.46%
# Ethereum Classic -1.47%
# NEM 0.38%
# Tezos -0.01%
# Zcash -0.68%
# VeChain -2.15%
# Bitcoin Gold 0.86%
# Maker 0.52%
# OmiseGO -2.1%
# Dogecoin -1.63%
# 0x -0.52%
# Qtum 3.13%
# Decred 0.54%
# Ontology -1.15%
# Basic Attention Token 8.55%
# Lisk 1.15%
# Aeternity 2.95%
# Zilliqa -2.35%
# Bitcoin Diamond 0.83%
# BitShares 0.76%
# Bytecoin 4.21%
# Nano -0.7%
# ICON -0.11%
# Siacoin 1.7%
# DigiByte -0.19%
# Steem 4.26%
# Pundi X -3.16%
# Verge 0.64%
# Bytom 2.84%
# Waves 0.39%
# Aurora 2.06%
# Metaverse ETP 2.93%
# Chainlink -0.3%
# Augur 1.03%
# Golem 3.35%
# TrueUSD 0.08%
# Stratis 4.0%
# Holo 3.15%
# Electroneum -3.84%
# Komodo -0.55%
# Paxos Standard Token -0.19%
# USD Coin 0.34%
# Status 0.82%
# Populous 1.5%
# Waltonchain 0.31%
# Cryptonex 2.57%
# Wanchain 2.61%
# MaidSafeCoin 5.07%
# Ardor -0.89%
# IOST -1.24%
# Mithril 3.34%
# KuCoin Shares -0.96%
# Aion 1.66%
# Ravencoin 2.58%
# Nexo -1.34%
# Bancor 0.26%
# WAX 1.88%
# Loopring 4.56%
# DigixDAO 1.98%
# GXChain 1.44%
# Decentraland -0.04%
# aelf 2.78%
# Ark -0.04%
# HyperCash -0.49%
# Huobi Token 0.21%
# Polymath 4.97%
# ReddCoin 0.67%
# Horizen 4.05%
# Veritaseum -1.56%
# PIVX 2.38%
# MonaCoin 0.0%
# QASH 0.66%
# Dentacoin 0.61%
# CyberMiles 3.45%
# MOAC 0.2%
# Crypto.com 0.35%
# Dai 0.49%
# Loom Network 3.17%
# Nxt 5.43%
# Mixin 11.78%
# FunFair -2.14%
# Nebulas 0.27%
# Theta Token 0.71%
# Revain 5.46%
# ETERNAL TOKEN 6.11%
# Dropil -3.24%

# %%
def average_price():
    n = 0
    array = []
    while n in range(len(data)):
        array.append(float(data[n]['price_rub']))
        n += 1
    print(sum(array) / len(data))

average_price()
# Out:
# 5916.982610264589
